# %%
import geopandas as gpd
import pandas as pd

# Set filepath
fp = "five_region_Output.shp"

# Read file using gpd.read_file()
data = gpd.read_file(fp)

# %%
data
# Out:
#   SRC_AGENCY       FIRE_ID      FIRENAME  YEAR  MONTH  DAY    REP_DATE  \
# 0         BC   2017-C10784          None  2017      7    7  2017-07-07
# 1         SK  20PA-ENGLISH  20PA-ENGLISH  2020      5    8  2020-05-08
# 2         MB   MB2018NE154          None  2018      7   28  2018-07-28
# 3         YT     2018WL005          None  2018      7    6  2018-07-06
# 4      PC-WB     2015WB004          None  2015      0    0        None
#
#    DATE_TYPE    OUT_DATE     DECADE  ...   POLY_DATE            CFS_REF_ID  \
# 0       None        None  2010-2019  ...  2017-09-09        BC-2017-C10784
# 1  Startdate  2020-06-08  2020-2029  ...  2020-07-07  SK-2020-20PA-ENGLISH
# 2  Startdate  2018-09-10  2010-2019  ...  2018-09-10   MB-2018-MB2018NE154
# 3       None        None  2010-2019  ...        None     YT-2018-2018WL005
# 4       None        None  2010-2019  ...        None  PC-WB-2015-2015WB004
#
#   CFS_NOTE1 CFS_NOTE2 AG_SRCFILE    ACQ_DATE SRC_AGY2 Fire2015_2  \
# ...

# %%
data['geometry']
# Out:
# 0    POLYGON Z ((-1868500.991 882646.206 0.000, -18...
# 1    POLYGON Z ((-645687.351 537486.236 0.000, -645...
# 2    MULTIPOLYGON Z (((-66913.002 1120152.995 0.000...
# 3    POLYGON Z ((-1757962.008 1738512.826 0.000, -1...
# 4    MULTIPOLYGON Z (((-1017837.775 1170629.011 0.0...
# Name: geometry, dtype: geometry

# %%
df = pd.DataFrame(data['geometry'])

# %%
df.to_csv("out.csv")

# %%
df['geometry'][0]

# %%
data
# Out:
#   SRC_AGENCY       FIRE_ID      FIRENAME  YEAR  MONTH  DAY    REP_DATE  \
# 0         BC   2017-C10784          None  2017      7    7  2017-07-07
# 1         SK  20PA-ENGLISH  20PA-ENGLISH  2020      5    8  2020-05-08
# 2         MB   MB2018NE154          None  2018      7   28  2018-07-28
# 3         YT     2018WL005          None  2018      7    6  2018-07-06
# 4      PC-WB     2015WB004          None  2015      0    0        None
#
#    DATE_TYPE    OUT_DATE     DECADE  ...   POLY_DATE            CFS_REF_ID  \
# 0       None        None  2010-2019  ...  2017-09-09        BC-2017-C10784
# 1  Startdate  2020-06-08  2020-2029  ...  2020-07-07  SK-2020-20PA-ENGLISH
# 2  Startdate  2018-09-10  2010-2019  ...  2018-09-10   MB-2018-MB2018NE154
# 3       None        None  2010-2019  ...        None     YT-2018-2018WL005
# 4       None        None  2010-2019  ...        None  PC-WB-2015-2015WB004
#
#   CFS_NOTE1 CFS_NOTE2 AG_SRCFILE    ACQ_DATE SRC_AGY2 Fire2015_2  \
# ...
